# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
files = ['../input/youtube-classification-result/result_FarCry6.csv','../input/youtube-classification-result/result_musicVideo_Gangnam.csv', '../input/youtube-classification-result/result_apology_my_response.csv',
   '../input/youtube-classification-result/result_gameTrailer_Pokemon.csv', '../input/youtube-classification-result/result_musicVideo_Baby.csv',
         '../input/youtube-classification-result/result_apology_my_overdue_apology.csv',
         '../input/youtube-classification-result/result_gameTrailer_CoD.csv', '../input/youtube-classification-result/result_musicVideo_Friday.csv', '../input/youtube-classification-result/result_apology_so_sorry.csv'
        ]
for idx, file in enumerate(files):
    print('---------------------------------------')
    print('file_name is {}'.format(file))
    
    dataset = pd.read_csv(file, lineterminator='\n')
    num_total_data = dataset.shape[0]
    
    potential_toxic = dataset[dataset['toxic'] >= 0.5].sort_values(by = 'toxic', ascending = False)
    potential_severetoxic = dataset[dataset['severe_toxic'] >= 0.5].sort_values(by = 'severe_toxic', ascending = False)
    potential_obscene = dataset[dataset['obscene'] >= 0.5].sort_values(by = 'obscene', ascending = False)
    potential_threat = dataset[dataset['threat'] >= 0.5].sort_values(by = 'threat', ascending = False)
    potential_insult = dataset[dataset['insult'] >= 0.5].sort_values(by = 'insult', ascending = False)
    potential_identity_hate = dataset[dataset['identity_hate'] >= 0.5].sort_values(by = 'identity_hate', ascending = False)
    
    text = " ".join(potential_toxic["comments"])
    wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="black").generate(text)
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud, interpolation='Bilinear')
    plt.axis("off")
    plt.figure(1,figsize=(12, 12))
    plt.show()
    
    print("percentage of bad comments")
    print("toxic: {}%, {} / {}".format(potential_toxic.shape[0] * 100 / num_total_data, potential_toxic.shape[0], num_total_data))
    print("severe toxic: {}%, {} / {}".format(potential_severetoxic.shape[0] * 100 / num_total_data, potential_severetoxic.shape[0], num_total_data))
    print("obscene: {}%, {} / {}".format(potential_obscene.shape[0] * 100 / num_total_data, potential_obscene.shape[0], num_total_data))
    print("threat: {}%, {} / {}".format(potential_threat.shape[0] * 100 / num_total_data, potential_threat.shape[0], num_total_data))
    print("insult: {}%, {} / {}".format(potential_insult.shape[0] * 100 / num_total_data, potential_insult.shape[0], num_total_data))
    print("identity hate: {}%, {} / {}".format(potential_identity_hate.shape[0] * 100 / num_total_data, potential_identity_hate.shape[0], num_total_data))
    
    
    

    print('------toxic comments----------')
    print(potential_toxic.head(10))
    print('------severe comments----------')
    print(potential_severetoxic.head(10))
    print('------obscene comments----------')
    print(potential_obscene.head(10))
    print('------threat comments----------')
    print(potential_threat.head(10))
    print('------insult comments----------')
    print(potential_insult.head(10))
    print('------identity hate comments----------')
    print(potential_identity_hate.head(10))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
for idx, file in enumerate(files):
    print('---------------------------------------')
    print('file_name is {}'.format(file))
    
    dataset = pd.read_csv(file, lineterminator='\n')
    num_total_data = dataset.shape[0]
    
    potential_toxic = dataset[dataset['toxic'] >= 0.5]
    potential_severetoxic = dataset[dataset['severe_toxic'] >= 0.5]
    potential_obscene = dataset[dataset['obscene'] >= 0.5]
    potential_threat = dataset[dataset['threat'] >= 0.5]
    potential_insult = dataset[dataset['insult'] >= 0.5]
    potential_identity_hate = dataset[dataset['identity_hate'] >= 0.5]
    
    text = " ".join(potential_toxic["comments"])
    wordcloud = WordCloud(max_words=200,colormap='Set3', background_color="black").generate(text)
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud, interpolation='Bilinear')
    plt.axis("off")
    plt.figure(1,figsize=(12, 12))
    plt.show()
